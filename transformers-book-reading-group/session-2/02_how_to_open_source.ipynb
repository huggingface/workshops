# %% [markdown]
# # How to Open Source?
#
# Delivered by: [Vaibhav (VB)](https://twitter.com/reach_vb)

# %% [markdown]
# # What is Open Source?
#
# OSS acronym for Open source software is software and its code is available to anyone who can use this software for free and can also modify their code.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # How to get started with Open Source?
#
# * Choosing where to contribute (finding orgs to contribute)
# * Understanding Codebase
# * Finding Issues
# * Making your first PR

# %% [markdown]
# # Hands-on demo
#
#
#
# * Identify a repo
# * Find an issue to work on
# * Fork the repo (`git clone https://github.com/<user-name>/transformers/`)
# * Create a new branch (`git checkout -b branch-name`)
# * Create a new remote to the upstream repo (`git remote add upstream https://github.com/huggingface/transformers`)
# * Make & commit those changes (`git add file-name && git commit -m "my first commit"`)
# * Create a PR (`git push -u origin branch-name`)
# * Work with the maintainers to make the PR worth merging
# * Merge the PR & celebrate
# * Bonus: Get a special mention in the next release
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Now it's your turn
#
# Pick an issue and get chopping
#
# * Transformers - https://github.com/huggingface/transformers/labels/Good%20First%20Issue
# * Datasets - https://github.com/huggingface/datasets/labels/good%20first%20issue
#
# P.S. Don't forget to checkout the contibuting guide: https://github.com/huggingface/transformers/blob/main/CONTRIBUTING.md

# %% [markdown]
# # More fun stuff
#
# * Every two weeks we'll review the list of merged PRs from #reading-group (https://hf.co/join/discord)
# * The most impactful PRs (judged by Lewis/ Leandro) will be awarded Huggingface swag (https://store.huggingface.co/) or a transformers book <3
#
# Happy contributing!
